# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:\\Users\\dental-1\\Documents\\dent_seg\\6_train_yolo_four_class_tooth_classification\\yolov5\\runs\\train\\teeth_classification4\\results.csv')
df.head()
# Out:
#                   epoch        train/box_loss        train/obj_loss  \
# 0                     0              0.107010               0.29688
# 1                     1              0.101490               0.31966
# 2                     2              0.094802               0.30631
# 3                     3              0.092256               0.31573
# 4                     4              0.090843               0.31104
#
#          train/cls_loss     metrics/precision        metrics/recall  \
# 0              0.043657              0.000000              0.000000
# 1              0.043180              0.000000              0.000000
# 2              0.043033              0.000309              0.004092
# 3              0.042475              0.002430              0.034577
# 4              0.042265              0.007856              0.118620
#
#         metrics/mAP_0.5  metrics/mAP_0.5:0.95          val/box_loss  \
# 0              0.000000              0.000000              0.100780
# ...

# %%
plt.figure(figsize=(10,7))
ax = sns.lineplot(data=df[['      metrics/recall']], palette='Greens', legend=False)
ax.set_title('Recall of Validation Data', fontsize = 20)
ax.set_xlabel('Epoch', fontsize=15)
ax.set_ylabel('Results', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(10,7))
ax = sns.lineplot(data=df[['   metrics/precision']], palette='Greens', legend=False)
ax.set_title('Precision of Validation Data', fontsize = 20)
ax.set_xlabel('Epoch', fontsize=15)
ax.set_ylabel('Results', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(10,7))
ax = sns.lineplot(data=df[['   metrics/precision', '      metrics/recall']], palette='Paired_r', legend=False)
ax.set_title('Precision Recall During Training of Test Data', fontsize = 20)
ax.set_xlabel('Epoch', fontsize=15)
ax.set_ylabel('Results', fontsize=15)
plt.legend(loc='lower right', labels=['Precision', 'Recall'], fontsize=15)
plt.show()

# %%
plt.figure(figsize=(10,7))
ax = sns.lineplot(data=df[['     metrics/mAP_0.5']], palette='Blues', legend=False)
ax.set_title('mAP 0.5 of Test Data', fontsize = 20)
ax.set_xlabel('Epoch', fontsize=15)
ax.set_ylabel('Results', fontsize=15)
plt.show()
